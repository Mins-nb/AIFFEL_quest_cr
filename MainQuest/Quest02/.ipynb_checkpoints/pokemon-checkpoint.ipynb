# %% [markdown]
# # 🦄 가랏, 몬스터볼! 전설의 포켓몬 찾아 삼만리

# %% [markdown]
# ## 첫번째 여정, 포켓몬 데이터 불러오기

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
from collections import Counter
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import os
original_data = pd.read_csv('/content/drive/MyDrive/Pokemon.csv')

# %%
pokemon = original_data.copy()
print(pokemon.shape)
pokemon.head()
# Out:
# (800, 13)
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
legendary = pokemon[pokemon["Legendary"] == True].reset_index(drop=True)
print(legendary.shape)
legendary.head()
# Out:
# (65, 13)
#      #                 Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 0  144             Articuno       Ice    Flying    580   90      85      100
# 1  145               Zapdos  Electric    Flying    580   90      90       85
# 2  146              Moltres      Fire    Flying    580   90     100       90
# 3  150               Mewtwo   Psychic       NaN    680  106     110       90
# 4  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       95      125     85           1       True
# 1      125       90    100           1       True
# 2      125       85     90           1       True
# 3      154       90    130           1       True
# 4      154      100    130           1       True

# %%
ordinary = pokemon[pokemon["Legendary"] == False].reset_index(drop=False)
print(ordinary.shape)
ordinary.head()
# Out:
# (735, 14)
#    index  #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1      1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2      2  3               Venusaur  Grass  Poison    525  80      82       83
# 3      3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4      4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## 두번째 여정, 데이터 전처리

# %%
pokemon["name_count"] = pokemon["Name"].apply(lambda i: len(i))
pokemon["long_name"] = pokemon["name_count"] >= 10
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  name_count  long_name
# 0       65       65     45           1      False           9      False
# 1       80       80     60           1      False           7      False
# 2      100      100     80           1      False           8      False
# 3      122      120     80           1      False          21       True
# 4       60       50     65           1      False          10       True

# %%
pokemon = pokemon.replace(to_replace="Nidoran♀", value="Nidoran X")
pokemon = pokemon.replace(to_replace="Nidoran♂", value="Nidoran Y")
pokemon = pokemon.replace(to_replace="Farfetch'd", value="Farfetchd")
pokemon = pokemon.replace(to_replace="Mr. Mime", value="Mr Mime")
pokemon = pokemon.replace(to_replace="Porygon2", value="Porygon Two")
pokemon = pokemon.replace(to_replace="Ho-oh", value="Ho Oh")
pokemon = pokemon.replace(to_replace="Mime Jr.", value="Mime Jr")
pokemon = pokemon.replace(to_replace="Porygon-Z", value="Porygon Z")
pokemon = pokemon.replace(to_replace="Zygarde50% Forme", value="Zygarde Forme")

# %%
pokemon["Name_nospace"] = pokemon["Name"].apply(lambda i: i.replace(" ", ""))
pokemon["name_isalpha"] = pokemon["Name_nospace"].apply(lambda i: i.isalpha())

pokemon[pokemon["name_isalpha"] == False]
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Type 2, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary, name_count, long_name, Name_nospace, name_isalpha]
# Index: []

# %%
def tokenize(name):
    tokens = []
    name_split = name.split(" ")
    for part_name in name_split:
        a = re.findall('[A-Z][a-z]*', part_name)
        tokens.extend(a)

    return np.array(tokens)

name = "CharizardMega Charizard X"
tokenize(name)
# Out:
# array(['Charizard', 'Mega', 'Charizard', 'X'], dtype='<U9')

# %%
all_tokens = list(legendary["Name"].apply(tokenize).values)

token_set = []
for token in all_tokens:
    token_set.extend(token)

print(len(set(token_set)))
print(token_set)
# Out:
# 65
# ...

# %%
most_common = Counter(token_set).most_common(10)
most_common
# Out:
# [('Forme', 15),
#  ('Mega', 6),
#  ('Mewtwo', 5),
#  ('Kyurem', 5),
#  ('Deoxys', 4),
#  ('Hoopa', 4),
#  ('Latias', 3),
#  ('Latios', 3),
#  ('Kyogre', 3),
#  ('Groudon', 3)]

# %%
for token, _ in most_common:
    pokemon[f"{token}"] = pokemon["Name"].str.contains(token)

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  ...  Fighting  Grass  Steel   Fire   Rock Psychic    Bug  \
# ...

# %%
types = list(set(pokemon["Type 1"]))
for t in types:
    pokemon[t] = (pokemon["Type 1"] == t) | (pokemon["Type 2"] == t)

pokemon[[["Type 1", "Type 2"] + types][0]].head()
# Out:
#   Type 1  Type 2  Ghost    Ice  Ground  Fairy  Flying  Electric  Poison  \
# 0  Grass  Poison  False  False   False  False   False     False    True
# 1  Grass  Poison  False  False   False  False   False     False    True
# 2  Grass  Poison  False  False   False  False   False     False    True
# 3  Grass  Poison  False  False   False  False   False     False    True
# 4   Fire     NaN  False  False   False  False   False     False   False
#
#    Dragon  Fighting  Grass  Steel   Fire   Rock  Psychic    Bug  Water   Dark  \
# 0   False     False   True  False  False  False    False  False  False  False
# 1   False     False   True  False  False  False    False  False  False  False
# 2   False     False   True  False  False  False    False  False  False  False
# 3   False     False   True  False  False  False    False  False  False  False
# 4   False     False  False  False   True  False    False  False  False  False
#
#    Normal
# 0   False
# 1   False
# 2   False
# 3   False
# ...

# %%
features = ['Total', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation']
target = 'Legendary'

X = original_data[features]
print(X.shape)
X.head()
# Out:
# (800, 8)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1

# %%
y = original_data[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 8) (640,)
# (160, 8) (160,)

# %% [markdown]
# ## 세번째 여정, 의사 결정 트리 모델 학습하기

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
model = DecisionTreeClassifier(random_state=25)
model
# Out:
# DecisionTreeClassifier(random_state=25)

# %%
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[144,   3],
#        [  5,   8]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      0.98      0.97       147
#         True       0.73      0.62      0.67        13
#
#     accuracy                           0.95       160
#    macro avg       0.85      0.80      0.82       160
# weighted avg       0.95      0.95      0.95       160

# %% [markdown]
# ## 네번째 여정, 베이스라인 모델 학습하기

# %%
print(len(pokemon.columns))
print(pokemon.columns)
# Out:
# 45
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'name_count',
#        'long_name', 'Name_nospace', 'name_isalpha', 'Forme', 'Mega', 'Mewtwo',
#        'Kyurem', 'Deoxys', 'Hoopa', 'Latias', 'Latios', 'Kyogre', 'Groudon',
#        'Ghost', 'Ice', 'Ground', 'Fairy', 'Flying', 'Electric', 'Poison',
#        'Dragon', 'Fighting', 'Grass', 'Steel', 'Fire', 'Rock', 'Psychic',
#        'Bug', 'Water', 'Dark', 'Normal'],
#       dtype='object')

# %%
features = ['Total', 'HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed', 'Generation',
            'name_count','long_name', 'Forme', 'Mega', 'Mewtwo','Deoxys', 'Kyurem', 'Latias', 'Latios',
            'Kyogre', 'Groudon', 'Hoopa','Poison', 'Ground', 'Flying', 'Normal', 'Water', 'Fire',
            'Electric','Rock', 'Dark', 'Fairy', 'Steel', 'Ghost', 'Psychic', 'Ice', 'Bug', 'Grass', 'Dragon', 'Fighting']

target = "Legendary"

X = pokemon[features]
print(X.shape)
X.head()
# Out:
# (800, 38)
#    Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  \
# 0    318  45      49       49       65       65     45           1
# 1    405  60      62       63       80       80     60           1
# 2    525  80      82       83      100      100     80           1
# 3    625  80     100      123      122      120     80           1
# 4    309  39      52       43       60       50     65           1
#
#    name_count  long_name  ...   Dark  Fairy  Steel  Ghost  Psychic    Ice  \
# 0           9      False  ...  False  False  False  False    False  False
# 1           7      False  ...  False  False  False  False    False  False
# 2           8      False  ...  False  False  False  False    False  False
# 3          21       True  ...  False  False  False  False    False  False
# 4          10       True  ...  False  False  False  False    False  False
#
#      Bug  Grass  Dragon  Fighting
# 0  False   True   False     False
# 1  False   True   False     False
# ...

# %%
y = pokemon[target]
print(y.shape)
y.head()
# Out:
# (800,)
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Legendary, dtype: bool

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=15)

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (640, 38) (640,)
# (160, 38) (160,)

# %%
model = DecisionTreeClassifier(random_state=25)
model #model을 실행하지 않았더니 리콜값이 그대로인 현상이 발생하여 model 실행
# Out:
# DecisionTreeClassifier(random_state=25)

# %%
#model = DecisionTreeClassifier(random_state=25)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print(conf_matrix)
# Out:
# [[141   6]
#  [  1  12]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.99      0.96      0.98       147
#         True       0.67      0.92      0.77        13
#
#     accuracy                           0.96       160
#    macro avg       0.83      0.94      0.87       160
# weighted avg       0.97      0.96      0.96       160

# %% [markdown]
# ## 다섯번째 여정, 비교 모델 학습하기

# %%
# 로지스틱 회귀로 정확도 예측하기
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression(solver='lbfgs', max_iter=3000) # iteration을 빼먹었더니 ConvergenceWarning이 발생하여 3000으로 설정
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("정확도 :", accuracy)
# Out:
# 정확도 : 0.9625

# %% [markdown]
# ## 여정의 마무리, 회고

# %% [markdown]
# 오늘은 케창딥 파트의 마무리, 메인 퀘스트를 진행했습니다.
#
# 노드를 따라가면 쉬울거라는 퍼실님의 말을 믿으며 힘차게 출발하였습니다.
#
# 노드를 따라갈 수가 없었습니다.... 수많은 오류들과 싸웠습니다.
#
# 어찌저찌 OpenAI와 그루님들의 조언을 통하여 해결했습니다. 하지만 아직도 디버깅흔적과 주석을 잘 달지 못하겠습니다. 시간이 부족해서 그런 것도 있지만요.
#
# 그래도 처음부터 끝까지 노드를 따라가면서 모델을 학습시키고, 피쳐 엔지니어링을 통해 리콜값을 0.62에서 0.92까지 끌어올렸을때 뿌듯했습니다.
#
# 데이터톤도 재밌게 진행해보고 싶습니다. 감사합니다.
